# %%
# Import

import requests
import pandas as pd
import json
import pprint
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import geopandas as gpd

# %%
# Load the GeoJSON file

path_object = Path('Resources/Bicycle_Thefts_Open_Data.geojson')

# %%
# Convert the data to a Pandas dataframe

df = gpd.read_file(path_object)
df.head(10)
# Out:
#    OBJECTID EVENT_UNIQUE_ID   PRIMARY_OFFENCE                   OCC_DATE  \
# 0         1  GO-20141261431       THEFT UNDER  2014-01-01T05:00:00+00:00
# 1         2  GO-20141263784  PROPERTY - FOUND  2014-01-01T05:00:00+00:00
# 2         3  GO-20141263544               B&E  2013-12-26T05:00:00+00:00
# 3         4  GO-20141266048       THEFT UNDER  2013-12-30T05:00:00+00:00
# 4         5  GO-20141267465       THEFT UNDER  2013-09-30T04:00:00+00:00
# 5         6  GO-20149000071       THEFT UNDER  2013-12-25T05:00:00+00:00
# 6         7  GO-20149000074       THEFT UNDER  2013-12-25T05:00:00+00:00
# 7         8  GO-20149000090       THEFT UNDER  2014-01-01T05:00:00+00:00
# 8         9  GO-20141272882       THEFT UNDER  2013-07-01T04:00:00+00:00
# 9        10  GO-20149000113       THEFT UNDER  2013-12-31T05:00:00+00:00
#
#    OCC_YEAR  OCC_MONTH    OCC_DOW  OCC_DAY  OCC_DOY  OCC_HOUR  ...  \
# 0      2014    January  Wednesday        1        1         7  ...
# ...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 31970 entries, 0 to 31969
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OBJECTID           31970 non-null  int64
#  1   EVENT_UNIQUE_ID    31970 non-null  object
#  2   PRIMARY_OFFENCE    31970 non-null  object
#  3   OCC_DATE           31970 non-null  object
#  4   OCC_YEAR           31970 non-null  int64
#  5   OCC_MONTH          31970 non-null  object
#  6   OCC_DOW            31970 non-null  object
#  7   OCC_DAY            31970 non-null  int64
#  8   OCC_DOY            31970 non-null  int64
#  9   OCC_HOUR           31970 non-null  int64
#  10  REPORT_DATE        31970 non-null  object
#  11  REPORT_YEAR        31970 non-null  int64
#  12  REPORT_MONTH       31970 non-null  object
#  13  REPORT_DOW         31970 non-null  object
#  14  REPORT_DAY         31970 non-null  int64
#  15  REPORT_DOY         31970 non-null  int64
# ...

# %%
# drop rows that have an NaN value 'bike cost' and columns ('LONG_WGS84', 'LAT_WGS84', 'HOOD_158', 'HOOD_140')

df_1 = df[df['BIKE_COST'].notna()]
df_new = df_1.drop(['HOOD_158', 'HOOD_140', 'geometry'], axis=1)
df_new.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 29808 entries, 2 to 31969
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OBJECTID           29808 non-null  int64
#  1   EVENT_UNIQUE_ID    29808 non-null  object
#  2   PRIMARY_OFFENCE    29808 non-null  object
#  3   OCC_DATE           29808 non-null  object
#  4   OCC_YEAR           29808 non-null  int64
#  5   OCC_MONTH          29808 non-null  object
#  6   OCC_DOW            29808 non-null  object
#  7   OCC_DAY            29808 non-null  int64
#  8   OCC_DOY            29808 non-null  int64
#  9   OCC_HOUR           29808 non-null  int64
#  10  REPORT_DATE        29808 non-null  object
#  11  REPORT_YEAR        29808 non-null  int64
#  12  REPORT_MONTH       29808 non-null  object
#  13  REPORT_DOW         29808 non-null  object
#  14  REPORT_DAY         29808 non-null  int64
#  15  REPORT_DOY         29808 non-null  int64
# ...

# %%
df_new['REPORT_DATE']
# Out:
# 2        2014-01-01T05:00:00+00:00
# 3        2014-01-02T05:00:00+00:00
# 4        2014-01-02T05:00:00+00:00
# 5        2014-01-02T05:00:00+00:00
# 6        2014-01-02T05:00:00+00:00
#                    ...
# 31963    2022-12-28T05:00:00+00:00
# 31964    2022-12-28T05:00:00+00:00
# 31966    2022-12-29T05:00:00+00:00
# 31968    2022-12-31T05:00:00+00:00
# 31969    2022-12-31T05:00:00+00:00
# Name: REPORT_DATE, Length: 29808, dtype: object

# %%
# convert the OCC_date and REPORT_DATE to datetime type
df_new['OCC_DATE'] = pd.to_datetime(df_new['OCC_DATE'])
df_new['REPORT_DATE'] = pd.to_datetime(df_new['REPORT_DATE'])
df_new['OCC_DATE'] = df_new['OCC_DATE'].dt.date
df_new['REPORT_DATE'] = df_new['REPORT_DATE'].dt.date
df_new.head()
# Out:
#    OBJECTID EVENT_UNIQUE_ID PRIMARY_OFFENCE    OCC_DATE  OCC_YEAR  OCC_MONTH  \
# 2         3  GO-20141263544             B&E  2013-12-26      2013   December
# 3         4  GO-20141266048     THEFT UNDER  2013-12-30      2013   December
# 4         5  GO-20141267465     THEFT UNDER  2013-09-30      2013  September
# 5         6  GO-20149000071     THEFT UNDER  2013-12-25      2013   December
# 6         7  GO-20149000074     THEFT UNDER  2013-12-25      2013   December
#
#      OCC_DOW  OCC_DAY  OCC_DOY  OCC_HOUR  ...   BIKE_MODEL  BIKE_TYPE  \
# 2   Thursday       26      360        19  ...          F59         RC
# 3     Monday       30      364        17  ...    VITAMIN A         OT
# 4     Monday       30      273         0  ...  CHARGER 9.2         MT
# 5  Wednesday       25      359        10  ...          NaN         TO
# 6  Wednesday       25      359        16  ...     RZ 120 1         MT
#
#   BIKE_SPEED BIKE_COLOUR  BIKE_COST  STATUS                NEIGHBOURHOOD_158  \
# ...

# %%
# LOAD
